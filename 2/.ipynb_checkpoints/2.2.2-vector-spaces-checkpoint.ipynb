# %% [markdown]
# # Векторные пространства
#
# ## Вектор
#
# В прошлый раз мы выяснили, что **вектор** — это набор из некоторого количества чисел. Например, в машинном обучении векторы используются, чтобы записывать признаки, числовые характеристики объектов, например магазинов или бутылок вина.
#
# <div>
#     <div style="#border: 1px solid gray;
#                 padding: 6px 0px 6px 0px;
#                 font-size: 18px;">
#         <div style="display: inline-block;
#                     border: 2px solid orange;
#                     border-radius: 4px;
#                     padding: 5px;
#                     ">
#         x = (
#         <div style="display: inline-block;
#                     border: 2px solid orange;
#                     border-radius: 4px;
#                     padding: 0px 5px 0px 5px;
#                     text-align: center;">x<sub>1</sub>, x<sub>2</sub>, ..., x<sub>n</sub></div> )
#         </div>
#     </div>
#     <div style="position: relative;
#                 display: inline-block;
#                 border: 2px solid orange;
#                 border-radius: 4px;
#                 margin: 0px 0px 20px 0px;
#                 padding: 2px 10px 2px 10px;
#                 top: 16px;
#                 left: 74px;
#                 text-align: center;">Числа
#         <div style="position: absolute;
#                     border-style: solid;
#                     border-width: 0 14px 30px 14px;
#                     border-color: transparent transparent orange transparent;
#                     top: -32px;
#                     left: 17px;
#                     "></div></div>
#     <div style="position: relative;
#                 display: inline-block;
#                 border: 2px solid orange;
#                 border-radius: 4px;
#                 padding: 2px 10px 2px 10px;
#                 top: -40px;
#                 left: 134px;
#                 text-align: center;">Признаковое описание магазина
#         <div style="position: absolute;
#                     border-style: solid;
#                     #border-width: 20px;
#                     border-width: 14px 30px 14px 30px;
#                     border-color: transparent orange transparent transparent;
#                     top: -2px;
#                     left: -60px;
#                     "></div></div>
# </div>

# %% [markdown]
# ## Векторное пространство
#
# Векторное пространство — это множество, которое обладает определенными свойствами. Тогда вектором будет называться любой элемент этого пространства.
#
# * Векторное пространство - множество
# * Вектор - элемент векторного пространства
#
# Векторное пространство — это некоторое множество $V$, на котором задано две операции:
#
# * Сложение двух векторов
# * Умножение вектора на число
#
# При этом операции должны быть замкнутыми, то есть сумма двух векторов должна давать снова вектор, а умножение любого числа на любой вектор должно давать снова опять же вектор. При этом сложение и умножение должны удовлетворять ряду аксиом, которые соответствуют нашей интуиции о том, как выглядят сложение и умножение. Дело в том, что элементами векторного пространства могут быть сложные объекты, необязательно числа. И операции могут вводиться довольно сложные. Но при этом интуиция не должна нас подводить, благодаря этим аксиомам. Итак, всё вместе, векторное пространство это:
#
# * Некоторое множество $V$
# * Доступно две операции:
#   * Сложение векторов
#   * Умножение вектора на число
# * Сумма любых двух векторов - вектор
# * Произведение любого вектора на любое число - вектор
# * Сумма и умножение на число должны удовлетворять 8 аксиомам

# %% [markdown]
# ## Аксиомы векторного пространства
#
# [Аксиомы](https://ru.wikipedia.org/wiki/%D0%90%D0%BA%D1%81%D0%B8%D0%BE%D0%BC%D0%B0) довольно сложные, мы не будем обсуждать их подробно, рассмотрим лишь два примера:
#
# <table style="border: 1px solid gray; width: 95%;">
#     <tr>
#         <th style="text-align: center; width: 40%;">Аксиома</th>
#         <th style="text-align: center; border: 1px solid; border-color: gray gray gray transparent;">Описание</th>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: gray gray transparent gray;">
#             $x + y = y + x$, для любых $x, y \in \mathbb{V}$
#         </td>
#         <td style="text-align: left;">Аксиома коммутативности, которая говорит, что от перестановки слагаемых сумма не меняется. Довольно разумно, правда?</td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $x + (y + z) = (x + y) + z$, для любых $x, y, z \in \mathbb{V}$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $\exists 0 \in \mathbb{V} : x + 0 = x \forall x \in \mathbb{V}$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $\forall x \in \mathbb{V} \exists - x \in \mathbb{V} : x + (-x) = 0$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $\alpha (\beta x) = (\alpha \beta)x$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $1 * x = x$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray transparent gray;">
#             $(\alpha + \beta) x = \alpha x + \beta x$
#         </td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; font-size: 14px; border: 1px solid; border-color: transparent gray gray gray;">
#             $\alpha (x + y) = \alpha x + \alpha y$
#         </td>
#         <td style="text-align: left;">Аксиома дистрибутивности, говорит, что произведение числа на сумму двух векторов равняется сумме двух векторов, умноженных на это число. То есть она нам говорит, что можно раскрывать скобки</td>
#     </tr>
# </table>

# %% [markdown]
# ## Векторное пространство
#
# Мы будем работать только с простыми векторными пространствами, которые называются [евклидовыми](https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D0%BA%D0%BB%D0%B8%D0%B4%D0%BE%D0%B2%D0%BE_%D0%BF%D1%80%D0%BE%D1%81%D1%82%D1%80%D0%B0%D0%BD%D1%81%D1%82%D0%B2%D0%BE).
#
# * Евклидово векторное пространство - $\mathbb{R}^n$
#
# Это пространства, которые состоят из векторов, каждый элемент которых — это [вещественные числа](https://ru.wikipedia.org/wiki/%D0%92%D0%B5%D1%89%D0%B5%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%BE%D0%B5_%D1%87%D0%B8%D1%81%D0%BB%D0%BE). Кстати, вещественное число — это любое дробное число, если вы пропустили курс матанализа. Евклидовы векторные пространства обозначаются красивой буквой $\mathbb{R}$ с верхним индексом n, где n — это число элементов в каждом векторе этого пространства. Их можно визуализировать, например:
#
# * $\mathbb{R}^2$ - все векторы из 2-х элементов. Это точки на плоскости
# * $\mathbb{R}^3$ - все векторы из 3-х элементов. Это точки в пространстве
#
# Как вводятся операции в евклидовом пространстве? Так, как это говорит наша интуиция, то есть поэлементно. Например, если мы хотим сложить два вектора $a$ и $b$ с элементами $(a_1, ..., a_n)$, $(b_1, ..., b_n)$, то их сумма — это вектор с элементами $(a_1 + b_1, a_2 + b_2, ..., a_n + b_n)$:
#
# * Поэлементное сложение:
#   * $a = (a_1, ..., a_n)$
#   * $b = (b_1, ..., b_n)$
#   * $a + b = (a_1 + b_1, ..., a_n + b_n)$
#
# Если мы хотим умножить вектор на число $\beta$, то результатом будет вектор, элементы которого являются $(\beta a_1, \beta a_2, ..., \beta a_n)$:
#
# * Поэлементное умножение на число:
#   * $a = (a_1, ..., a_n)$
#   * $\beta \in \mathbb{R}$
#   * $\beta a = (\beta a_1, ..., \beta a_n)$
#
# Пример. Дано 2 вектора:
#
# * $a = (1, 2, 0)$
# * $b = (2, 0, 1)$
#
# Чему будет равно $3a + 5b$? Решение:
#
# 1. Умножаем число 3 на каждый элемент вектора $a = (3, 6, 0)$
# 2. Умножаем число 5 на каждый элемент вектора $b = (10, 0, 5)$
# 3. Суммируем каждый элемент из одного и второго вектора: $(3, 6, 0) + (10, 0, 5) = (13, 6, 5)$

# %% [markdown]
# ## Пример - сорт вина
#
# Мы хотим определить сорт винограда, из которого сделано вино, для каждой бутылки. В этом случае векторное пространство — это все возможные описания вина. Все возможные признаковые описания бутылок. При этом конкретный вектор — это описание конкретной бутылки. Эти векторы можно усреднять:
#
# $$\overline{x} = \frac{1}{m} \sum\limits_{i=1}^m (x_1^i, ..., x_n^i)$$
#
# То есть, к примеру, мы можем посчитать среднее признаковое описание для конкретного сорта. Для этого уже можно делать некоторый анализ данных. Например, после этого мы можем искать сорт с наибольшим содержанием алкоголя.

# %% [markdown]
# ## Резюме
#
# Что мы узнали?
#
# * С помощью векторов в машинном обучении описываются объекты реального мира
# * Неформально, вектор - набор чисел
# * Формально, вектор - элемент векторного пространства
# * Векторное пространство - множество с двумя операциями и рядом аксиом
#
# С помощью векторов в машинном обучении описываются объекты реального мира. При этом вектор, неформально определяется как просто набор из чисел. Формально же он задается как элемент векторного пространства. В эту очередь, векторное пространство — это некоторое множество с двумя операциями (сложение и умножение на число) и некоторыми аксиомами.
