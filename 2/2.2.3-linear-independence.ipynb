# %% [markdown]
# # Линейная независимость
#
# ## Признаковое описание
#
# В прошлый раз мы рассматривали пример с магазинами, когда мы хотим предсказать прибыль каждого из магазинов в следующем месяце. Допустим, у нас есть 100 магазинов, каждый из которых описывается десятью признаками, десятью числами. Тогда мы можем составить таблицу размера 100 x 10, где каждая строка будет соответствовать признаковому описанию одного магазина, а каждый столбец — набору значений одного признака на всех магазинах:

# %% [markdown]
# <div style="position: relative; padding-top: 60px;">
#
#  <div style="position: absolute;
#              border: 2px solid orange;
#              border-radius: 4px;
#              padding: 2px 6px 2px 6px;
#              top:  0px;
#              left: 124px;
#              font-size: 14px;
#             ">Признак
#  <div style="position: absolute;
#              border-style: solid;
#              border-width: 30px 14px 30px 14px;
#              border-color: orange transparent transparent transparent;
#              top:  25px;
#              left: 19px;"></div>
#  </div>
#
#
#
# <div style="position: absolute;
#             border: 2px solid orange;
#             border-radius: 4px;
#             padding: 2px 6px 2px 6px;
#             #top: 6.2em;
#             top: 151px;
#             left: 28em;
#             font-size: 14px;
#             ">Магазин
# <div style="position: absolute;
#             border-style: solid;
#             border-width: 14px 30px 14px 30px;
#             border-color: transparent orange transparent transparent;
#             top:  -2px;
#             left: -60px;"></div>
# </div>
#
#
# <div style="display: inline-block; position: relative; border: 1px solid gray;">
# <table style="width: 360px; height: 300px;">
#     <tr>
#         <td>1</td>
#         <td style="width: 25%;">36.18</td>
#         <td>2</td>
#         <td style="border: 2px solid; border-color: orange orange transparent orange;">2</td>
#         <td>2</td>
#         <td>3</td>
#         <td style="width: 15%;">59090</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>46.47671233</td>
#         <td>1</td>
#         <td style="border: 2px solid; border-color: transparent orange transparent orange;">0</td>
#         <td>4</td>
#         <td>3</td>
#         <td>14773</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>45.13434658</td>
#         <td>2</td>
#         <td style="border: 2px solid; border-color: transparent orange orange orange;">0</td>
#         <td>3</td>
#         <td>3</td>
#         <td>19376</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr style="border: 2px solid orange;">
#         <td>4</td>
#         <td>25.88766123</td>
#         <td>4</td>
#         <td style="border: 2px solid orange;">1</td>
#         <td>4</td>
#         <td>3</td>
#         <td>16098</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>25.70410959</td>
#         <td>4</td>
#         <td style="border: 2px solid; border-color: orange orange transparent orange;">1</td>
#         <td>3</td>
#         <td>3</td>
#         <td>20338</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>33.03</td>
#         <td>1</td>
#         <td style="border: 2px solid; border-color: transparent orange transparent orange;">0</td>
#         <td>3</td>
#         <td>1</td>
#         <td>501667</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>46.44931597</td>
#         <td>4</td>
#         <td style="border: 2px solid; border-color: transparent orange transparent orange;">3</td>
#         <td>2</td>
#         <td>1</td>
#         <td>26100</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#         <td style="border: 2px solid; border-color: transparent orange transparent orange;">...</td>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#     </tr>
#     <tr>
#         <td>99</td>
#         <td>51.24383562</td>
#         <td>2</td>
#         <td style="border: 2px solid; border-color: transparent orange transparent orange;">0</td>
#         <td>4</td>
#         <td>2</td>
#         <td>20727</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>100</td>
#         <td>46.8739726</td>
#         <td>2</td>
#         <td style="border: 2px solid; border-color: transparent orange orange orange;">0</td>
#         <td>1</td>
#         <td>3</td>
#         <td>27861</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
# </table>
# </div>
#
# </div>

# %% [markdown]
# Раньше в качестве векторов мы рассматривали строки этой таблицы, то есть каждый вектор являлся признаковым описанием одного магазина. Сейчас ситуация будет противоположная, в качестве векторов мы будем рассматривать столбцы этой таблицы. То есть один вектор будет содержать значение одного признака на всех магазинах:
#
# <div style="position: relative; margin-top:30px; font-size: 14px; font-family: Arial, DejaVu Serif;">
#
#     <div style="position: relative;">
#         <div style="position: absolute;
#                     border: 2px solid orange;
#                     top: -0.5em;
#                     left: 10.5em;
#                     padding: 0px 20px 80px 0px;
#                     ">
#         </div>
#         <div style="position: absolute;
#                     border: 2px solid orange;
#                     top: -0.5em;
#                     left: 15.3em;
#                     padding: 0px 20px 80px 0px;
#                     ">
#         </div>
#         <div style="position: absolute; top: -2em; left: 11em;">$ x_1 $</div>
#         <div style="position: absolute; top: -2em; left: 15.8em;">$ x_n $</div>
#     </div>
#
# $
# \begin{bmatrix}
#     10 & \dots & 4 \\
#     \vdots & \ddots & \vdots \\
#     35 & \dots & 1 \\
# \end{bmatrix}
# \longrightarrow
# \begin{bmatrix}
#     10 & \dots & 4 \\
#     \vdots & \ddots & \vdots \\
#     35 & \dots & 1 \\
# \end{bmatrix}
# $
#
# </div>
#
# * Вектор - набор значений одного из признаков
#
# Что, если вектор первого признака равен вектору второго признака, умноженного на 1000?
#
# * Что, если $x_1 = 1000 x_2$?
#
# Это может означать, что и первый, и второй признаки — это суммарный вес товаров, которые завезут в магазин в следующем месяце. Но при этом первый признак равен этому весу в граммах, а второй — в килограммах.
#
# * Первый признак - вес в граммах
# * Второй признак - вес в килограммах
#
# Понятно, что это избыточная информация. Нам не нужно знать значения этого признака и в одной, и в другой единице измерения. Достаточно знать лишь одно из этого.
#
# Вот второй пример:
#
# * Что, если $x_3 = 0.5 x_4 + 0.5 x_5$ или $x_3 = (x_4 + x_5) 0.5$?
# * 4-й и 5-й признаки - прибыль магазина в прошлом и позапрошлом месяце
# * 3-й признак - средняя прибыль за последние 2 месяца
#
# Представьте, что третий признак равен среднему значению четвёртого и пятого признаков. Это может означать, что четвёртый признак — это прибыль магазина в прошлом месяце. Пятый признак — прибыль в позапрошлом месяце. Тогда значение третьего признака имеет смысл средней прибыли магазина за последние два месяца. Это снова избыточная информация.

# %%
x4 = 100
x5 = 120

print(0.5*x4 + 0.5*x5)

print((x4 + x5)/2)
print((x4 + x5)*0.5)
# Out:
# 110.0
# 110.0
# 110.0

# %% [markdown]
# ## Линейная зависимость
#
# Эта ситуация, в которой один вектор выражается как сумма с коэффициентами других векторов, называется линейной зависимостью.
#
# * Линейная зависимость — один вектор равен сумме с весами других векторов
#
# Линейная зависимость — это довольно плохо. Дело в том, что она приводит к избыточности информации. Мы храним те векторы, которые на самом деле выражаются через остальные довольно простым способом. Также мы тратим дополнительные ресурсы на хранение лишней информации. Тоже не очень хорошо: приводит к лишним денежным затратам. Также линейная зависимость вредит некоторым методам машинного обучения, например линейным. Об этом мы будем говорить в следующих занятиях.
#
# * Избыточная информация
# * Лишние затраты на хранение данных
# * Вредит некоторым методам машинного обучения
#
# Дадим формальное определение:
#
# * Пусть дан набор векторов $x_1, ..., x_n$
#
# xi-тая — это один вектор, значение признаков, значение одного признака на всех объектах.
#
# * Векторы линейно зависимы, если существуют такие числа как $\beta_1, ..., \beta_n$, хотя бы одно из которых не равно нулю, что сумма векторов с такими коэффициентами равна нулю:
#
# <div style="position: relative; padding-bottom: 40px;">
#
# $$\beta_1 x_1 + ... + \beta_n x_n = 0$$
#
#
# <div style="position: absolute;
#             border-style: solid;
#             border-width: 0 14px 30px 14px;
#             border-color: transparent transparent orange transparent;
#             top: 20px;
#             left: 545px;
#             "></div>
#
# <div style="position: absolute;
#             display: inline-block;
#             border: 2px solid orange;
#             padding: 2px 10px 2px 10px;
#             top: 50px;
#             left: 480px;">
#     Вектор из всех нулей
# </div>
#
# </div>
#
# Кстати, обратите внимание: в этом уравнении слева стоит сумма с коэффициентами векторов, то есть это тоже вектор, значит и справа должен стоять вектор из всех нулей, который мы просто обозначаем нулем, как и вещественное число.
#
# Можно дать немного альтернативное определение линейной зависимости.
#
# * Векторы линейно зависимы, если один из них линейно выражается через остальные:
#
# $$ x_i = \beta_1 x_1 + ... + \beta_{i-1} x_{i-1} + \beta_{i+1} x_{i+1} + ... + \beta_n x_n $$
#
# Возьмём вектор, в нашем примере это i‐тый вектор, при котором коэффициент не равен нулю. Перенесём этот вектор в другую часть равенства, поделим на коэффициент βi-тая, переобозначим коэффициенты и получим аналогичное определение: система векторов линейно зависимая, если один из них выражается через все остальные.

# %% [markdown]
# ## Особенность определения
#
# Обратите внимание на одну особенность этого определения:
#
# * Если один из векторов нулевой, то все они линейно зависимы
#   * Возьмем коэффициент при нулевом векторе равным 1
#   * При остальных - равным 0
#   * Определение будет выполнено
#
# Дело в том, что мы можем взять коэффициент перед нулевым вектором равным единице, при остальных векторах коэффициенты — ноль, и определение линейной зависимости будет выполнено. Это вполне логично: если один из векторов нулевой, он не содержит в себе никакой информации, сразу система становится избыточной.

# %% [markdown]
# ## Линейная зависимость
#
# Опеределение линейной независимости дать просто: Система векторов линейно независимая, если для неё не выполнено определение линейной зависимости. Или, что то же самое, уравнение $\beta_1 x_1 + ... + \beta_n x_n$ равно нулю только в том случае, если все коэффициенты $\beta_1, \beta_2, ..., \beta_n$ равны нулю:
#
# * Пусть дан набор векторов $x_1, ..., x_n$
# * Они линейно независимы, если уравнение: $\beta_1 x_1 + ... + \beta_n x_n = 0$ выполнено только при $\beta_1 = \beta_1 = ... \beta_n = 0$
#
# Это и есть опеределение линейной независимости.

# %% [markdown]
# ## Пример
#
# Пусть дано три вектора из евклидова пространства $\mathbb{R^3}$, то есть векторы длины три:
#
# * $x_1 = (2, 1, 2)$
# * $x_2 = (4, 2, 4)$
# * $x_3 = (1, 2, 3)$
#
# Если мы возьмём первый вектор, умножим его на два и вычтем второй вектор, то получим нулевой вектор:
#
# * $2 x_1 - x_2 + 0 x_3 = 0$

# %%
import numpy as np

x1 = np.array((2, 1, 2))
x2 = np.array((4, 2, 4))
x3 = np.array((1, 2, 3))

print('(x1_{} * 2)={} - x2_{} = {}'.format(x1, x1 * 2, x2, x1 * 2 - x2))
# print(x1 * 2 - x2 + 0 * x3)
# Out:
# (x1_[2 1 2] * 2)=[4 2 4] - x2_[4 2 4] = [0 0 0]

# %% [markdown]
# Это значит, что эта система векторов **линейно зависима**. А что будет, если мы заменим первую координату во втором векторе с четвёрки на пятёрку?
#
# * $x_1 = (2, 1, 2)$
# * $x_2 = (5, 2, 4)$
# * $x_3 = (1, 2, 3)$
#
# Оказывается, система станет **линейно независимой**.

# %% [markdown]
# ## Как это можно было понять?
#
# Есть два способа. Первый из них — это метод Гаусса, который позволяет привести систему векторов к такому виду, в котором будет очевидно — она является линейно зависимой или линейно независимой. Но мы не будем его изучать, потому что есть гораздо более простой способ: вычислить ранг системы векторов, например, на компьютере.
#
# * Вариант 1 - метод Гаусса
# * Вариант 2 - вычислить ранг

# %% [markdown]
# ## Размерность векторного пространства
#
# Напоследок поговорим о ещё одном важном понятии, которое вытекает из линейной независимости — это размерность. Пусть дано некоторое векторное пространство $\mathbb{V}$. Максимальное число **линейно независимых** векторов в нём и называется размерностью этого пространства и обозначается как $dim \mathbb{V}$.
#
# * Векторное пространство $\mathbb{V}$
# * Максимальное число линейно независимых векторов в нём и называется размерностью
# * Обозначение $dim \mathbb{V}$
#
# Например, для евклидова пространства $\mathbb{R}^n$ размерность равняется как раз таки $n$, то есть длине вектора в нём:
#
# * $dim \mathbb{R}^n = n$
#
# Это легко показать. Представьте себе систему векторов, где вектор $e_i$ имеет следующий вид: в нём ровно одна координата — i‐тая — равна единице, а все остальные координаты равны нулю:
#
# * Пример системы независимых векторов:
#   * $e_1 = (1, 0, ..., 0)$
#   * $e_2 = (0, 1, ..., 0)$
#   * $e_n = (0, 0, ..., 1)$
#
# Эти векторы линейно независимы, но при этом любой другой вектор в $\mathbb{R}^n$ выражается линейно через них. Такой набор векторов, через который выражается любой другой вектор, называется **базисом векторного пространства**.

# %% [markdown]
# ## Резюме
#
# Что мы узнали?
#
# * Линейная зависимость
# * Установить линейную зависимость можно с помощью ранга
# * Размерность векторного пространства
#
# Понятие линейной зависимости позволяет выявлять избыточность информации в системе векторов. Векторы линейно зависимы, если один из них выражается через все остальные. При этом установить факт линейной зависимости или независимости можно, вычислив ранг системы векторов. Также мы ввели понятие размерности векторного пространства — это максимальное число линейно независимых векторов в нём.
