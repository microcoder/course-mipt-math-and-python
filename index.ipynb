# %% [markdown]
# # Математика и Python для анализа данных
#
# https://www.coursera.org/learn/mathematics-and-python
#
# ## Неделя 1
#
# ### Python, уровень 0
#
# * [Что такое Python и почему мы выбрали именно его](1/1.2.1-why-python.ipynb)?
# * [Установка Anaconda](1/1.2.2-4-installation.ipynb)
# * [Знакомство с Jupyter Notebook](1/1.2.5-jupyter-notebook.ipynb)
# * [Знакомство с Jupyter Notebook](1/1.2.5-jupyter-notebook.ipynb)
#
# ### Знакомство с синтаксисом Python
#
# * [Типы данных](1/1.3.1-data-type.ipynb)
# * [Циклы, функции, генераторы, list comprehension](1/1.3.3-loop-function-generators.ipynb)
# * [Чтение, запись данных из файлов](1/1.3.5-8-files.ipynb)
#
# ### Производная и её применение
#
# * [Функции и их свойства](1/1.4.1-functions-and-properties.ipynb)
# * [Предел и производная](1/1.4.2-limit-and-derivative.ipynb)
# * [Геометрический смысл производной](1/1.4.3-geo-derivative.ipynb)
# * [Производная сложной функции](1/1.4.4-derivative-complex-function.ipynb)
# * [Задача нахождения экстремума](1/1.4.5-task-extremum.ipynb)
# * [Вторая производная и выпуклость](1/1.4.6-second-derivative-and-convexity.ipynb)
#
# ## Неделя 2
#
# ### Библиотеки NumPy, Matplotlib, SciPy, Pandas
#
# * [Pandas. Data Frame](2/2.1.1-pandas-data-frame.ipynb)
# * [Pandas. Индексация и селекция](2/2.1.2-pandas-index-and-select.ipynb)
# * [Первое знакомство NumPy, SciPy и Matplotlib](2/2.1.3-numpy-scipy-matplotlib.ipynb)
# * [Решение оптимизационных задач в SciPy](2/2.1.4-scipy.ipynb)
#
# ### Линейная алгебра. Векторы
#
# * [Знакомство с линейной алгеброй](2/2.2.1-linear-algebra.ipynb)
# * [Векторные пространства](2/2.2.2-vector-spaces.ipynb)
# * [Линейная независимость](2/2.2.3-linear-independence.ipynb)
# * [Операции в векторных пространствах](2/2.2.4-operations-in-vector-spaces.ipynb)
# * [NumPy: векторы и операции над ними](2/2.2.5-vector-operations.ipynb)
#
# ### Линейная алгебра. Матрицы
#
# * [Зачем нужны матрицы?](2/2.3.1-why-are-matrix-needed.ipynb)
# * [Матричные операции](2/2.3.2-matrix-operations.ipynb)
# * [Ранг и определитель](2/2.3.3-rank-and-determinant.ipynb)
# * [Системы линейных уравнений](2/2.3.4-systems-of-linear-equations.ipynb)
# * [Особые виды матриц](2/2.3.5-special-types-of-matrices.ipynb)
# * [Собственные числа и векторы](2/2.3.6-numbers-and-vectors.ipynb)
# * [NumPy: матрицы и операции над ними](2/2.3.7-numpy-matrix-operations.ipynb)
#
# ## Неделя 3
#
# ### Градиент и оптимизация гладких функций
#
# * [Частные производные и градиент](3/3.1.1-private-derivatives-and-gradient.ipynb)
